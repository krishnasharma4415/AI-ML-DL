# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('title_transactions.csv')
df.head()
# Out:
#                     electric_vehicle_type    vin_1_10  model_year       make  \
# 0          Battery Electric Vehicle (BEV)  5YJXCBE2XG        2016      TESLA
# 1          Battery Electric Vehicle (BEV)  5YJXCBE49H        2017      TESLA
# 2          Battery Electric Vehicle (BEV)  5YJXCBE49H        2017      TESLA
# 3  Plug-in Hybrid Electric Vehicle (PHEV)  1G1RA6S59H        2017  CHEVROLET
# 4  Plug-in Hybrid Electric Vehicle (PHEV)  1G1RA6S59H        2017  CHEVROLET
#
#      model new_or_used_vehicle  sale_price         transaction_date  \
# 0  Model X                 New    102000.0  2017-01-31T00:00:00.000
# 1  Model X                 New         0.0  2017-03-22T00:00:00.000
# 2  Model X                 New    166250.0  2017-03-22T00:00:00.000
# 3     Volt                 New         0.0  2017-03-24T00:00:00.000
# 4     Volt                 New     32499.0  2017-03-24T00:00:00.000
#
#         transaction_type  transaction_year  ... dol_vehicle_id  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 433172 entries, 0 to 433171
# Data columns (total 30 columns):
#  #   Column                                                   Non-Null Count   Dtype
# ---  ------                                                   --------------   -----
#  0   electric_vehicle_type                                    433172 non-null  object
#  1   vin_1_10                                                 433172 non-null  object
#  2   model_year                                               433172 non-null  int64
#  3   make                                                     433172 non-null  object
#  4   model                                                    433172 non-null  object
#  5   new_or_used_vehicle                                      433172 non-null  object
#  6   sale_price                                               433172 non-null  float64
#  7   transaction_date                                         433172 non-null  object
# ...

# %%
df['transaction_date'] = pd.to_datetime(df['transaction_date'], errors='coerce')

# %%
df['month'] = df['transaction_date'].dt.month
df['quartile'] = df['transaction_date'].dt.quarter

# %%
top_10 = df['county'].value_counts().nlargest(10).index

# %%
df_top = df[df['county'].isin(top_10)]

# %%
df_brand_year = df_top.groupby(['county', 'make', 'model_year']).size().reset_index(name='vehicle_count')
df_brand_year.to_csv('counties_brand_year.csv', index=False)
print(df_brand_year.info())
df_brand_year.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1389 entries, 0 to 1388
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   county         1389 non-null   object
#  1   make           1389 non-null   object
#  2   model_year     1389 non-null   int64
#  3   vehicle_count  1389 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 43.5+ KB
# None
#    county  make  model_year  vehicle_count
# 0  Benton  AUDI        2016              4
# 1  Benton  AUDI        2017              5
# 2  Benton  AUDI        2019              2
# 3  Benton  AUDI        2020              7
# 4  Benton  AUDI        2021              6

# %%
df_brand_quartile_year = df_top.groupby(['county', 'make', 'quartile', 'model_year']).size().reset_index(name='vehicle_count')
df_brand_quartile_year.to_csv('counties_brand_quartile_year.csv', index=False)
print(df_brand_quartile_year.info())
df_brand_quartile_year.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4488 entries, 0 to 4487
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   county         4488 non-null   object
#  1   make           4488 non-null   object
#  2   quartile       4488 non-null   int32
#  3   model_year     4488 non-null   int64
#  4   vehicle_count  4488 non-null   int64
# dtypes: int32(1), int64(2), object(2)
# memory usage: 157.9+ KB
# None
#    county  make  quartile  model_year  vehicle_count
# 0  Benton  AUDI         1        2016              2
# 1  Benton  AUDI         1        2017              5
# 2  Benton  AUDI         1        2020              5
# 3  Benton  AUDI         1        2021              4
# 4  Benton  AUDI         2        2016              2

# %%
df_brand_month_year = df_top.groupby(['county', 'make', 'month', 'model_year']).size().reset_index(name='vehicle_count')
df_brand_month_year.to_csv('counties_brand_month_year.csv', index=False)
print(df_brand_month_year.info())
df_brand_month_year.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10867 entries, 0 to 10866
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   county         10867 non-null  object
#  1   make           10867 non-null  object
#  2   month          10867 non-null  int32
#  3   model_year     10867 non-null  int64
#  4   vehicle_count  10867 non-null  int64
# dtypes: int32(1), int64(2), object(2)
# memory usage: 382.2+ KB
# None
#    county  make  month  model_year  vehicle_count
# 0  Benton  AUDI      1        2017              2
# 1  Benton  AUDI      1        2020              1
# 2  Benton  AUDI      2        2017              2
# 3  Benton  AUDI      2        2021              4
# 4  Benton  AUDI      3        2016              2
